# %%
import requests
import os
import inspect
from langchain_openai import OpenAIEmbeddings
from openai import OpenAI
import httpx
from typing import Any
from qdrant_client.http.models import Payload 
from qdrant_client import QdrantClient
from qdrant_client.models import VectorParams, Distance

# %% [markdown]
# # Тестируем Rag

# %%
x = RetreiveReranker(5, 1)

# %%
test_payload = """
Музей космонавтики
""" 
x.retrieve_and_rerank(test_payload)
# Out:
# [{'id': '5',
#   'text': 'Музей космонавтики. Адрес: 129515, Москва, метро ВДНХ, проспект Мира, 111. Телефон: +7 499 750-23-00 (доб. 1016). Электронная почта: museikosmonavtiki@culture.mos.ru. Музей расположен в непосредственной близости от ВДНХ, вход через павильон №17. Есть сувенирный магазин, кафе, доступна аудиоэкскурсия. Проводятся тематические экскурсии, лекции, образовательные программы. Для посетителей доступны услуги экскурсовода, предусмотрена парковка. Доступно посещение с детьми, есть специальные программы для школьников. Музей участвует в акциях «Ночь музеев» и «Дни открытых дверей». Также функционирует Мемориальный дом-музей академика С.П. Королёва с отдельным режимом работы.',
#   'score': 0.9993884563446045}]
