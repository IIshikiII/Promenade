# %%
from promenade.models import *
from promenade.agents import *

# %% [markdown]
# # Building graph

# %%
agent = build_reranker_graph(
    llm=llm
)

# %%
result = await agent.ainvoke(
    {
        "input_query": "Как работает пушкинский музей",
        "reranked_documents": None,
        "retrieved_count": None,
        "result": None
    }
)
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  5.92it/s]

# %%
print(result["result"])
# Out:
# Главное здание. Base url: https://pushkinmuseum.art/
#
# ## Главное здание
# **Часы работы**
# - Вторник: 10:00–21:00
# - Среда: 10:00–19:00
# - Четверг: 10:00–21:00
# - Пятница: 11:00–21:00
# - Суббота: 10:00–21:00
# - Воскресенье: 10:00–19:00
# - Понедельник: выходной
#
# **Стоимость билетов**
# — информация отсутствует —
#
# **Актуальные выставки и события**
# - **Князья Барятинские. Искусство для наследников** (21.04.2026 – 05.07.2026): выставка, посвящённая истории и коллекциям княжеского рода.
# - **Ларионов / Гончарова. Начало** (31.03.2026 – 28.06.2026): экспозиция ранних работ художников в зале 31.
# - **«Московский Витрувий» в ГМИИ им. А.С. Пушкина** (27.01.2026 – 31.05.2026): выставка в зале 7, посвящённая архитектуре.
#
# **Специальные предложения**
# - Режим работы изменён в майские праздники (подробности на сайте).
# - Возможны особенности работы касс (подробности на сайте).
#
# **Адрес и контакты**
# - Адрес: Москва, ул. Волхонка, 12
# ...
